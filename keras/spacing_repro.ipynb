# %% [markdown]
# this is `"apple"`

# %% [markdown]
# Use the command ` > git commit -m "F issue - ix-removed"` to commit your changes.

# %% [markdown]
# The code snippet `for i` is broken into two `in range(10):` will iterate through numbers 0 to 9.

# %% [markdown]
# To highlight a word, wrap it in backticks like `completely changed`.

# %% [markdown]
# In Markdown, you can create inline code using backticks: `var x = 5;_trailing_add`. The function `add_calculate_average(data)` computes the mean of a dataset.

# %% [markdown]
# Wrap program output like `Error: File not found_add_crossing` code boundary in backticks.

# %% [markdown]
# The CSS class leading_add `corssing_code_boundary.highlight` adds a background color to elements.

# %% [markdown]
# One - Enclose command-line inputs: `python inside add script.py --input data.txt`. The command `sudo update` refreshes package information. - inside removed

# %% [markdown]
# ### One
#
# - this line is `changed`. Next one is deleted.
# - The code snippet `<html>for i in range(10):<html>` will iterate through numbers 0 to 9.

# %% [markdown]
# ### Two
# - Enclose `--input data.txt`.
# - The command `sudo` package information.
# - The code snippet `i in range` will iterate through numbers 0 to 9.

# %% [markdown]
# ### Three
#
# - Enclose command-line inputs: `python script.py --input data.txt`.
# - this line is `added now`. previous is as-is next is deleted across boundary.
# - The command `sudo` information.
# - The `in range(10):` will iterate through numbers 0 to 9.

# %% [markdown]
# Use the command `git commit -m "Fix issue"` to commit your changes.

# %% [markdown]
# The code snippet `for i in range(10):` will iterate through numbers 0 to 9.

# %% [markdown]
# To highlight a word, wrap it in backticks like `this`.

# %% [markdown]
# In Markdown, you can create inline code using backticks: `var x = 5;`. The function `calculate_average(data)` computes the mean of a dataset.

# %% [markdown]
# Wrap program output like `Error: File not found` in backticks.

# %% [markdown]
# The CSS class `.highlight` adds a background color to elements.

# %% [markdown]
# One - Enclose command-line inputs: `python script.py --input data.txt`. The command `sudo apt-get update` refreshes package information.

# %% [markdown]
# ### One
#
# - Enclose command-line inputs: `python script.py --input data.txt`.
# - The command `sudo apt-get update` refreshes package information.
# - The code snippet `for i in range(10):` will iterate through numbers 0 to 9.

# %% [markdown]
# ### Two
# - Enclose command-line inputs: `python script.py --input data.txt`.
# - The command `sudo apt-get update` refreshes package information.
# - The code snippet `for i in range(10):` will iterate through numbers 0 to 9.

# %% [markdown]
# ### Three
#
# - Enclose command-line inputs: `python script.py --input data.txt`.
# - The command `sudo apt-get update` refreshes package information.
# - The code snippet `for i in range(10):` will iterate through numbers 0 to 9.

# %% [markdown]
# this is `"apple"`
