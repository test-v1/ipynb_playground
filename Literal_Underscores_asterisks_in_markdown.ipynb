# %% [markdown]
# single underscore _user_type_ parameter

# %% [markdown]
# single asterisk *user *asd type* parameter

# %% [markdown]
# double asterisk **variable_1*two**

# %% [markdown]
# double_underscore __variable_1*two__

# %% [markdown]
# underscore _this is long_variable in italics_

# %% [markdown]
# this is ``middle ` tick`` in markdown

# %% [markdown]
# ###  Multiple special chars within

# %% [markdown]
# multi underscore _user_type_is_1_ parameter

# %% [markdown]
# multi asterisk *user *asd *type* parameter

# %% [markdown]
# double asterisk **variable_1 ** two**

# %% [markdown]
# double_underscore __variable __ adsa __ *two__

# %% [markdown]
# backticks within backticks `` `var1` `` are here

# %% [markdown]
# > block quote with another > in it

# %% [markdown]
# ## Heading with # in it

# %% [markdown]
# - bullet list with - in it

# %% [markdown]
# 1. Ordered list with 1. in it
