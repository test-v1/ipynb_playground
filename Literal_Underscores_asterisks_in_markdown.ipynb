# %% [markdown]
# single _new_user_type_ parameter

# %% [markdown]
# single _new_*type*_arc_ asterisk *user *asd type* parameter

# %% [markdown]
# double asterisk **v*two**

# %% [markdown]
# double_underscore variable_1*two

# %% [markdown]
# underscore _this is long_variable added italics_

# %% [markdown]
# this is ``middle `another` tick`` in markdown

# %% [markdown]
# ###  Multiple special chars within

# %% [markdown]
# multi underscore _use_r1_ parameter

# %% [markdown]
# multi *asterisk* *user *asd *type* parameter

# %% [markdown]
# double asterisk *variable_1**two*

# %% [markdown]
# double_underscore _sync alt_

# %% [markdown]
# backticks within backticks `` var1 `` are here

# %% [markdown]
# >> block quote with another > in it

# %% [markdown]
# ## Heading with # in it

# %% [markdown]
# - bullet list with - in it

# %% [markdown]
# 1. Ordered list with 1. in it

# %% [markdown]
# **hello **_**how**_** are you**

# %% [markdown]
# single underscore _user_type_ parameterb _gdg edg_

# %% [markdown]
# _user_ty! cd_pe_ parameter

# %% [markdown]
# he is _<user_
