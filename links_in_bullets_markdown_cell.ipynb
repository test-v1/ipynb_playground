# %% [markdown]
# ## Heading
#  * this is [linked page](https://www.google.com) in bullets
#  * another [page v2](https://www.google.com/[abc]/def) with square bracket in URL
#  * no link here

# %% [markdown]
#  * this is [linked page](https://www.google.com) in bullets

# %% [markdown]
# ## Heading
#  * this is [linked page](https://www.google.com) in bullets
#  * another [page v2](https://www.google.com/[abc]/def) with square bracket in URL
#  * no link here
